# %%
import pickle
with open('id_kp.pkl', 'rb') as f:
    x = pickle.load(f)

# %%
from azure.cosmos import exceptions, CosmosClient, PartitionKey
from bs4 import BeautifulSoup, SoupStrainer
import requests
import re
import pickle
def getKenpomWeb():
    url = "https://kenpom.com"
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.152 Safari/537.36'})
    data = page.text
    soup = BeautifulSoup(data, "html.parser")
    table = soup.find('table', id="ratings-table")
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    return rows

# %%
rows = getKenpomWeb()

# %%
def team_name(team):
    team  = re.sub(r'\d+', '', team)
    team = team.rstrip()
    return team

# %%
teams = []
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    if len(cols) == 0:
        pass
    else:
        teams.append(team_name(cols[1]))

# %%
x
# Out:
# {'12': 'Arizona',
#  '8': 'Arkansas',
#  '2000': 'Abilene Christian',
#  '2005': 'Air Force',
#  '2006': 'Akron',
#  '2010': 'Alabama A&M',
#  '333': 'Alabama',
#  '2011': 'Alabama St.',
#  '399': 'Albany',
#  '2016': 'Alcorn St.',
#  '44': 'American',
#  '2026': 'Appalachian St.',
#  '9': 'Arizona St.',
#  '2032': 'Arkansas St.',
#  '2029': 'Arkansas Pine Bluff',
#  '349': 'Army',
#  '2': 'Auburn',
#  '2046': 'Austin Peay',
#  '252': 'BYU',
#  '2050': 'Ball St.',
#  '239': 'Baylor',
#  '91': 'Bellarmine',
#  '2057': 'Belmont',
#  '2065': 'Bethune Cookman',
#  '2066': 'Binghamton',
#  '68': 'Boise St.',
#  '103': 'Boston College',
#  '104': 'Boston University',
#  '189': 'Bowling Green',
#  '71': 'Bradley',
#  '225': 'Brown',
#  '2803': 'Bryant',
#  '2083': 'Bucknell',
#  '2084': 'Buffalo',
#  '2086': 'Butler',
#  '2934': 'Cal St. Bakersfield',
#  '2239': 'Cal St. Fullerton',
#  '2463': 'Cal St. Northridge',
#  '13': 'Cal Poly',
#  '2856': 'Cal Baptist',
#  '25': 'California',
#  '2097': 'Campbell',
#  '2099': 'Canisius',
#  '2110': 'Central Arkansas',
#  '2115': 'Central Connecticut',
#  '2117': 'Central Michigan',
#  '232': 'Charleston',
#  '2127': 'Charleston Southern',
#  '2429': 'Charlotte',
#  '236': 'Chattanooga',
#  '2130': 'Chicago St.',
#  '2132': 'Cincinnati',
#  '228': 'Clemson',
#  '325': 'Cleveland St.',
#  '324': 'Coastal Carolina',
#  '2142': 'Colgate',
#  '38': 'Colorado',
#  '36': 'Colorado St.',
#  '171': 'Columbia',
#  '2154': 'Coppin St.',
#  '172': 'Cornell',
#  '156': 'Creighton',
#  '159': 'Dartmouth',
#  '2166': 'Davidson',
#  '2168': 'Dayton',
#  '305': 'DePaul',
#  '48': 'Delaware',
#  '2169': 'Delaware St.',
#  '2172': 'Denver',
#  '2174': 'Detroit Mercy',
#  '3101': 'Dixie St.',
#  '2181': 'Drake',
#  '2182': 'Drexel',
#  '150': 'Duke',
#  '2184': 'Duquesne',
#  '151': 'East Carolina',
#  '2193': 'East Tennessee St.',
#  '2197': 'Eastern Illinois',
#  '2198': 'Eastern Kentucky',
#  '2199': 'Eastern Michigan',
#  '331': 'Eastern Washington',
#  '2210': 'Elon',
#  '339': 'Evansville',
#  '2217': 'Fairfield',
#  '161': 'Fairleigh Dickinson',
#  '50': 'Florida A&M',
#  '2226': 'Florida Atlantic',
#  '57': 'Florida',
#  '526': 'Florida Gulf Coast',
#  '2229': 'FIU',
#  '52': 'Florida St.',
#  '2230': 'Fordham',
#  '278': 'Fresno St.',
#  '231': 'Furman',
#  '2241': 'Gardner Webb',
#  '2244': 'George Mason',
#  '45': 'George Washington',
#  '46': 'Georgetown',
#  '61': 'Georgia',
#  '290': 'Georgia Southern',
#  '2247': 'Georgia St.',
#  '59': 'Georgia Tech',
#  '2250': 'Gonzaga',
#  '2755': 'Grambling St.',
#  '2253': 'Grand Canyon',
#  '2739': 'Green Bay',
#  '2261': 'Hampton',
#  '42': 'Hartford',
#  '108': 'Harvard',
#  '62': 'Hawaii',
#  '2272': 'High Point',
#  '2275': 'Hofstra',
#  '107': 'Holy Cross',
#  '2277': 'Houston Baptist',
#  '248': 'Houston',
#  '47': 'Howard',
#  '85': 'IUPUI',
#  '304': 'Idaho St.',
#  '70': 'Idaho',
#  '356': 'Illinois',
#  '2287': 'Illinois St.',
#  '2916': 'Incarnate Word',
#  '84': 'Indiana',
#  '282': 'Indiana St.',
#  '314': 'Iona',
#  '2294': 'Iowa',
#  '66': 'Iowa St.',
#  '2296': 'Jackson St.',
#  '294': 'Jacksonville',
#  '55': 'Jacksonville St.',
#  '256': 'James Madison',
#  '140': 'UMKC',
#  '2305': 'Kansas',
#  '2306': 'Kansas St.',
#  '338': 'Kennesaw St.',
#  '2309': 'Kent St.',
#  '96': 'Kentucky',
#  '99': 'LSU',
#  '2325': 'La Salle',
#  '322': 'Lafayette',
#  '2320': 'Lamar',
#  '2329': 'Lehigh',
#  '2335': 'Liberty',
#  '288': 'Lipscomb',
#  '2031': 'Little Rock',
#  '299': 'Long Beach St.',
#  '112358': 'LIU',
#  '2344': 'Longwood',
#  '309': 'Louisiana',
#  '2348': 'Louisiana Tech',
#  '97': 'Louisville',
#  '2352': 'Loyola MD',
#  '2350': 'Loyola Chicago',
#  '2351': 'Loyola Marymount',
#  '311': 'Maine',
#  '2363': 'Manhattan',
#  '2368': 'Marist',
#  '269': 'Marquette',
#  '276': 'Marshall',
#  '120': 'Maryland',
#  '2379': 'Maryland Eastern Shore',
#  '2377': 'McNeese St.',
#  '235': 'Memphis',
#  '2382': 'Mercer',
#  '2771': 'Merrimack',
#  '193': 'Miami OH',
#  '2390': 'Miami FL',
#  '127': 'Michigan St.',
#  '130': 'Michigan',
#  '2393': 'Middle Tennessee',
#  '270': 'Milwaukee',
#  '135': 'Minnesota',
#  '344': 'Mississippi St.',
#  '2400': 'Mississippi Valley St.',
#  '2623': 'Missouri St.',
#  '142': 'Missouri',
#  '2405': 'Monmouth',
#  '149': 'Montana',
#  '147': 'Montana St.',
#  '2413': 'Morehead St.',
#  '2415': 'Morgan St.',
#  '116': "Mount St. Mary's",
#  '93': 'Murray St.',
#  '152': 'N.C. State',
#  '2885': 'NJIT',
#  '2426': 'Navy',
#  '158': 'Nebraska',
#  '2440': 'Nevada',
#  '160': 'New Hampshire',
#  '167': 'New Mexico',
#  '166': 'New Mexico St.',
#  '2443': 'New Orleans',
#  '315': 'Niagara',
#  '2447': 'Nicholls St.',
#  '2450': 'Norfolk St.',
#  '2453': 'North Alabama',
#  '2448': 'North Carolina A&T',
#  '2428': 'North Carolina Central',
#  '153': 'North Carolina',
#  '155': 'North Dakota',
#  '2449': 'North Dakota St.',
#  '2454': 'North Florida',
#  '249': 'North Texas',
#  '111': 'Northeastern',
#  '2464': 'Northern Arizona',
#  '2458': 'Northern Colorado',
#  '2459': 'Northern Illinois',
#  '2460': 'Northern Iowa',
#  '94': 'Northern Kentucky',
#  '2466': 'Northwestern St.',
#  '77': 'Northwestern',
#  '87': 'Notre Dame',
#  '2473': 'Oakland',
#  '195': 'Ohio',
#  '194': 'Ohio St.',
#  '201': 'Oklahoma',
#  '197': 'Oklahoma St.',
#  '295': 'Old Dominion',
#  '145': 'Mississippi',
#  '2437': 'Nebraska Omaha',
#  '198': 'Oral Roberts',
#  '2483': 'Oregon',
#  '204': 'Oregon St.',
#  '279': 'Pacific',
#  '213': 'Penn St.',
#  '219': 'Penn',
#  '2492': 'Pepperdine',
#  '221': 'Pittsburgh',
#  '2501': 'Portland',
#  '2502': 'Portland St.',
#  '2504': 'Prairie View A&M',
#  '2506': 'Presbyterian',
#  '163': 'Princeton',
#  '2507': 'Providence',
#  '2509': 'Purdue',
#  '2870': 'Purdue Fort Wayne',
#  '2514': 'Quinnipiac',
#  '2515': 'Radford',
#  '227': 'Rhode Island',
#  '242': 'Rice',
#  '257': 'Richmond',
#  '2520': 'Rider',
#  '2523': 'Robert Morris',
#  '164': 'Rutgers',
#  '2545': 'Southeastern Louisiana',
#  '2565': 'SIU Edwardsville',
#  '2567': 'SMU',
#  '16': 'Sacramento St.',
#  '2529': 'Sacred Heart',
#  '2603': "Saint Joseph's",
#  '139': 'Saint Louis',
#  '2608': "Saint Mary's",
#  '2612': "Saint Peter's",
#  '2534': 'Sam Houston St.',
#  '2535': 'Samford',
#  '21': 'San Diego St.',
#  '301': 'San Diego',
#  '2539': 'San Francisco',
#  '23': 'San Jose St.',
#  '2541': 'Santa Clara',
#  '2547': 'Seattle',
#  '2550': 'Seton Hall',
#  '2561': 'Siena',
#  '6': 'South Alabama',
#  '2579': 'South Carolina',
#  '2569': 'South Carolina St.',
#  '2908': 'USC Upstate',
#  '233': 'South Dakota',
#  '2571': 'South Dakota St.',
#  '58': 'South Florida',
#  '2546': 'Southeast Missouri St.',
#  '79': 'Southern Illinois',
#  '2582': 'Southern',
#  '2572': 'Southern Miss',
#  '253': 'Southern Utah',
#  '179': 'St. Bonaventure',
#  '2597': 'St. Francis NY',
#  '2598': 'St. Francis PA',
#  '2599': "St. John's",
#  '2900': 'St. Thomas',
#  '24': 'Stanford',
#  '2617': 'Stephen F. Austin',
#  '56': 'Stetson',
#  '2619': 'Stony Brook',
#  '183': 'Syracuse',
#  '2628': 'TCU',
#  '2627': 'Tarleton St.',
#  '218': 'Temple',
#  '2634': 'Tennessee St.',
#  '2635': 'Tennessee Tech',
#  '2633': 'Tennessee',
#  '245': 'Texas A&M',
#  '357': 'Texas A&M Corpus Chris',
#  '251': 'Texas',
#  '2640': 'Texas Southern',
#  '326': 'Texas St.',
#  '2641': 'Texas Tech',
#  '2643': 'The Citadel',
#  '2649': 'Toledo',
#  '119': 'Towson',
#  '2653': 'Troy',
#  '2655': 'Tulane',
#  '202': 'Tulsa',
#  '5': 'UAB',
#  '302': 'UC Davis',
#  '300': 'UC Irvine',
#  '27': 'UC Riverside',
#  '28': 'UC San Diego',
#  '2540': 'UC Santa Barbara',
#  '2116': 'UCF',
#  '26': 'UCLA',
#  '41': 'Connecticut',
#  '82': 'Illinois Chicago',
#  '2433': 'Louisiana Monroe',
#  '2378': 'UMBC',
#  '2349': 'UMass Lowell',
#  '113': 'Massachusetts',
#  '2427': 'UNC Asheville',
#  '2430': 'UNC Greensboro',
#  '350': 'UNC Wilmington',
#  '2439': 'UNLV',
#  '30': 'USC',
#  '250': 'UT Arlington',
#  '2630': 'Tennessee Martin',
#  '292': 'UT Rio Grande Valley',
#  '2638': 'UTEP',
#  '2636': 'UTSA',
#  '328': 'Utah St.',
#  '254': 'Utah',
#  '3084': 'Utah Valley',
#  '2670': 'VCU',
#  '2678': 'VMI',
#  '2674': 'Valparaiso',
#  '238': 'Vanderbilt',
#  '261': 'Vermont',
#  '222': 'Villanova',
#  '258': 'Virginia',
#  '259': 'Virginia Tech',
#  '2681': 'Wagner',
#  '154': 'Wake Forest',
#  '264': 'Washington',
#  '265': 'Washington St.',
#  '2692': 'Weber St.',
#  '277': 'West Virginia',
#  '2717': 'Western Carolina',
#  '2710': 'Western Illinois',
#  '98': 'Western Kentucky',
#  '2711': 'Western Michigan',
#  '2724': 'Wichita St.',
#  '2729': 'William & Mary',
#  '2737': 'Winthrop',
#  '275': 'Wisconsin',
#  '2747': 'Wofford',
#  '2750': 'Wright St.',
#  '2751': 'Wyoming',
#  '2752': 'Xavier',
#  '43': 'Yale',
#  '2754': 'Youngstown St.'}

# %%
dict_teams = []
for key, value in x.items():
    dict_teams.append(value)

# %%
dict_teams
# Out:
# ['Arizona',
#  'Arkansas',
#  'Abilene Christian',
#  'Air Force',
#  'Akron',
#  'Alabama A&M',
#  'Alabama',
#  'Alabama St.',
#  'Albany',
#  'Alcorn St.',
#  'American',
#  'Appalachian St.',
#  'Arizona St.',
#  'Arkansas St.',
#  'Arkansas Pine Bluff',
#  'Army',
#  'Auburn',
#  'Austin Peay',
#  'BYU',
#  'Ball St.',
#  'Baylor',
#  'Bellarmine',
#  'Belmont',
#  'Bethune Cookman',
#  'Binghamton',
#  'Boise St.',
#  'Boston College',
#  'Boston University',
#  'Bowling Green',
#  'Bradley',
#  'Brown',
#  'Bryant',
#  'Bucknell',
#  'Buffalo',
#  'Butler',
#  'Cal St. Bakersfield',
#  'Cal St. Fullerton',
#  'Cal St. Northridge',
#  'Cal Poly',
#  'Cal Baptist',
#  'California',
#  'Campbell',
#  'Canisius',
#  'Central Arkansas',
#  'Central Connecticut',
#  'Central Michigan',
#  'Charleston',
#  'Charleston Southern',
#  'Charlotte',
#  'Chattanooga',
#  'Chicago St.',
#  'Cincinnati',
#  'Clemson',
#  'Cleveland St.',
#  'Coastal Carolina',
#  'Colgate',
#  'Colorado',
#  'Colorado St.',
#  'Columbia',
#  'Coppin St.',
#  'Cornell',
#  'Creighton',
#  'Dartmouth',
#  'Davidson',
#  'Dayton',
#  'DePaul',
#  'Delaware',
#  'Delaware St.',
#  'Denver',
#  'Detroit Mercy',
#  'Utah Tech',
#  'Drake',
#  'Drexel',
#  'Duke',
#  'Duquesne',
#  'East Carolina',
#  'East Tennessee St.',
#  'Eastern Illinois',
#  'Eastern Kentucky',
#  'Eastern Michigan',
#  'Eastern Washington',
#  'Elon',
#  'Evansville',
#  'Fairfield',
#  'Fairleigh Dickinson',
#  'Florida A&M',
#  'Florida Atlantic',
#  'Florida',
#  'Florida Gulf Coast',
#  'FIU',
#  'Florida St.',
#  'Fordham',
#  'Fresno St.',
#  'Furman',
#  'Gardner Webb',
#  'George Mason',
#  'George Washington',
#  'Georgetown',
#  'Georgia',
#  'Georgia Southern',
#  'Georgia St.',
#  'Georgia Tech',
#  'Gonzaga',
#  'Grambling St.',
#  'Grand Canyon',
#  'Green Bay',
#  'Hampton',
#  'Hartford',
#  'Harvard',
#  'Hawaii',
#  'High Point',
#  'Hofstra',
#  'Holy Cross',
#  'Houston Christian',
#  'Houston',
#  'Howard',
#  'IUPUI',
#  'Idaho St.',
#  'Idaho',
#  'Illinois',
#  'Illinois St.',
#  'Incarnate Word',
#  'Indiana',
#  'Indiana St.',
#  'Iona',
#  'Iowa',
#  'Iowa St.',
#  'Jackson St.',
#  'Jacksonville',
#  'Jacksonville St.',
#  'James Madison',
#  'UMKC',
#  'Kansas',
#  'Kansas St.',
#  'Kennesaw St.',
#  'Kent St.',
#  'Kentucky',
#  'LSU',
#  'La Salle',
#  'Lafayette',
#  'Lamar',
#  'Lehigh',
#  'Liberty',
#  'Lipscomb',
#  'Little Rock',
#  'Long Beach St.',
#  'LIU',
#  'Longwood',
#  'Louisiana',
#  'Louisiana Tech',
#  'Louisville',
#  'Loyola MD',
#  'Loyola Chicago',
#  'Loyola Marymount',
#  'Maine',
#  'Manhattan',
#  'Marist',
#  'Marquette',
#  'Marshall',
#  'Maryland',
#  'Maryland Eastern Shore',
#  'McNeese St.',
#  'Memphis',
#  'Mercer',
#  'Merrimack',
#  'Miami OH',
#  'Miami FL',
#  'Michigan St.',
#  'Michigan',
#  'Middle Tennessee',
#  'Milwaukee',
#  'Minnesota',
#  'Mississippi St.',
#  'Mississippi Valley St.',
#  'Missouri St.',
#  'Missouri',
#  'Monmouth',
#  'Montana',
#  'Montana St.',
#  'Morehead St.',
#  'Morgan St.',
#  "Mount St. Mary's",
#  'Murray St.',
#  'N.C. State',
#  'NJIT',
#  'Navy',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Mexico',
#  'New Mexico St.',
#  'New Orleans',
#  'Niagara',
#  'Nicholls St.',
#  'Norfolk St.',
#  'North Alabama',
#  'North Carolina A&T',
#  'North Carolina Central',
#  'North Carolina',
#  'North Dakota',
#  'North Dakota St.',
#  'North Florida',
#  'North Texas',
#  'Northeastern',
#  'Northern Arizona',
#  'Northern Colorado',
#  'Northern Illinois',
#  'Northern Iowa',
#  'Northern Kentucky',
#  'Northwestern St.',
#  'Northwestern',
#  'Notre Dame',
#  'Oakland',
#  'Ohio',
#  'Ohio St.',
#  'Oklahoma',
#  'Oklahoma St.',
#  'Old Dominion',
#  'Mississippi',
#  'Nebraska Omaha',
#  'Oral Roberts',
#  'Oregon',
#  'Oregon St.',
#  'Pacific',
#  'Penn St.',
#  'Penn',
#  'Pepperdine',
#  'Pittsburgh',
#  'Portland',
#  'Portland St.',
#  'Prairie View A&M',
#  'Presbyterian',
#  'Princeton',
#  'Providence',
#  'Purdue',
#  'Purdue Fort Wayne',
#  'Quinnipiac',
#  'Radford',
#  'Rhode Island',
#  'Rice',
#  'Richmond',
#  'Rider',
#  'Robert Morris',
#  'Rutgers',
#  'Southeastern Louisiana',
#  'SIU Edwardsville',
#  'SMU',
#  'Sacramento St.',
#  'Sacred Heart',
#  "Saint Joseph's",
#  'Saint Louis',
#  "Saint Mary's",
#  "Saint Peter's",
#  'Sam Houston St.',
#  'Samford',
#  'San Diego St.',
#  'San Diego',
#  'San Francisco',
#  'San Jose St.',
#  'Santa Clara',
#  'Seattle',
#  'Seton Hall',
#  'Siena',
#  'South Alabama',
#  'South Carolina',
#  'South Carolina St.',
#  'USC Upstate',
#  'South Dakota',
#  'South Dakota St.',
#  'South Florida',
#  'Southeast Missouri St.',
#  'Southern Illinois',
#  'Southern',
#  'Southern Miss',
#  'Southern Utah',
#  'St. Bonaventure',
#  'St. Francis NY',
#  'St. Francis PA',
#  "St. John's",
#  'St. Thomas',
#  'Stanford',
#  'Stephen F. Austin',
#  'Stetson',
#  'Stony Brook',
#  'Syracuse',
#  'TCU',
#  'Tarleton St.',
#  'Temple',
#  'Tennessee St.',
#  'Tennessee Tech',
#  'Tennessee',
#  'Texas A&M',
#  'Texas A&M Corpus Chris',
#  'Texas',
#  'Texas Southern',
#  'Texas St.',
#  'Texas Tech',
#  'The Citadel',
#  'Toledo',
#  'Towson',
#  'Troy',
#  'Tulane',
#  'Tulsa',
#  'UAB',
#  'UC Davis',
#  'UC Irvine',
#  'UC Riverside',
#  'UC San Diego',
#  'UC Santa Barbara',
#  'UCF',
#  'UCLA',
#  'Connecticut',
#  'Illinois Chicago',
#  'Louisiana Monroe',
#  'UMBC',
#  'UMass Lowell',
#  'Massachusetts',
#  'UNC Asheville',
#  'UNC Greensboro',
#  'UNC Wilmington',
#  'UNLV',
#  'USC',
#  'UT Arlington',
#  'Tennessee Martin',
#  'UT Rio Grande Valley',
#  'UTEP',
#  'UTSA',
#  'Utah St.',
#  'Utah',
#  'Utah Valley',
#  'VCU',
#  'VMI',
#  'Valparaiso',
#  'Vanderbilt',
#  'Vermont',
#  'Villanova',
#  'Virginia',
#  'Virginia Tech',
#  'Wagner',
#  'Wake Forest',
#  'Washington',
#  'Washington St.',
#  'Weber St.',
#  'West Virginia',
#  'Western Carolina',
#  'Western Illinois',
#  'Western Kentucky',
#  'Western Michigan',
#  'Wichita St.',
#  'William & Mary',
#  'Winthrop',
#  'Wisconsin',
#  'Wofford',
#  'Wright St.',
#  'Wyoming',
#  'Xavier',
#  'Yale',
#  'Youngstown St.',
#  'Queens',
#  'Southern Indiana',
#  'Lindenwood',
#  'Stonehill']

# %%
x['2837'] = "Texas A&M Commerce"

# %%
for team in teams:
    if team not in dict_teams:
        print(team)

# %%
len(x)
# Out:
# 363

# %%
with open('id_kp.pkl', 'wb') as handle:
    pickle.dump(x, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle
with open('conf_kp_sportsreference.pickle', 'rb') as f:
    x = pickle.load(f)

# %%
x['ind'] = 'IND'

# %%
with open('conf_kp_sportsreference.pickle', 'wb') as handle:
    pickle.dump(x, handle, protocol=pickle.HIGHEST_PROTOCOL)
