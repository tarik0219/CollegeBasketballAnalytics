# %%
import os
import pickle
for filename in os.listdir():
    try:
        old = filename.split('.png')[0]
        new = kp_espn[sportsrefernce_kp[old]]
        print(new+".png")
        os.rename(filename, new+""
    except:
        pass
    #os.rename(filename
# Out:
# Abilene Christian Wildcats.png
# Air Force Falcons.png
# Akron Zips.png
# Alabama A&M Bulldogs.png
# Alabama Crimson Tide.png
# Alabama State Hornets.png
# UAB Blazers.png
# Albany Great Danes.png
# Alcorn State Braves.png
# American University Eagles.png
# Appalachian State Mountaineers.png
# Arizona State Sun Devils.png
# Arizona Wildcats.png
# Arkansas Razorbacks.png
# Arkansas State Red Wolves.png
# Arkansas-Pine Bluff Golden Lions.png
# Army Black Knights.png
# Auburn Tigers.png
# Austin Peay Governors.png
# Ball State Cardinals.png
# Baylor Bears.png
# Bellarmine Knights.png
# Belmont Bruins.png
# Bethune-Cookman Wildcats.png
# Binghamton Bearcats.png
# Boise State Broncos.png
# Boston College Eagles.png
# Boston University Terriers.png
# Bowling Green Falcons.png
# Bradley Braves.png
# Brown Bears.png
# Bryant Bulldogs.png
# Bucknell Bison.png
# Buffalo Bulls.png
# Butler Bulldogs.png
# BYU Cougars.png
# Cal Poly Mustangs.png
# CSU Bakersfield Roadrunners.png
# ...

# %%
with open('kp_sportsrefernce.pickle', 'rb') as handle:
    kp_sportsrefernce = pickle.load(handle)
sportsrefernce_kp = {v: k for k, v in kp_sportsrefernce.items()}

# %%
with open('espn_kp.pickle', 'rb') as handle:
    espn_kp = pickle.load(handle)
kp_espn = {v: k for k, v in espn_kp.items()}

# %%
sportsrefernce_kp
# Out:
# {'Abilene Christian Wildcats': 'Abilene Christian',
#  'Air Force Falcons': 'Air Force',
#  'Akron Zips': 'Akron',
#  'Alabama A&M Bulldogs': 'Alabama A&M',
#  'Alabama Crimson Tide': 'Alabama',
#  'Alabama State Hornets': 'Alabama St.',
#  'Alabama-Birmingham Blazers': 'UAB',
#  'Albany (NY) Great Danes': 'Albany',
#  'Alcorn State Braves': 'Alcorn St.',
#  'American Eagles': 'American',
#  'Appalachian State Mountaineers': 'Appalachian St.',
#  'Arizona State Sun Devils': 'Arizona St.',
#  'Arizona Wildcats': 'Arizona',
#  'Arkansas Razorbacks': 'Arkansas',
#  'Arkansas State Red Wolves': 'Arkansas St.',
#  'Arkansas-Pine Bluff Golden Lions': 'Arkansas Pine Bluff',
#  'Army Black Knights': 'Army',
#  'Auburn Tigers': 'Auburn',
#  'Austin Peay Governors': 'Austin Peay',
#  'Ball State Cardinals': 'Ball St.',
#  'Baylor Bears': 'Baylor',
#  'Bellarmine Knights': 'Bellarmine',
#  'Belmont Bruins': 'Belmont',
#  'Binghamton Bearcats': 'Binghamton',
# ...

# %%
kp_espn
# Out:
# {'Temple': 'Temple Owls',
#  'Boise St.': 'Boise State Broncos',
#  'Utah St.': 'Utah State Aggies',
#  'New Mexico St.': 'New Mexico State Aggies',
#  'Colorado St.': 'Colorado State Rams',
#  'Bradley': 'Bradley Braves',
#  'Dixie St.': 'Dixie State Trailblazers',
#  'Texas St.': 'Texas State Bobcats',
#  'Clemson': 'Clemson Tigers',
#  'St. Bonaventure': 'St. Bonaventure Bonnies',
#  'Penn': 'Pennsylvania Quakers',
#  'Davidson': 'Davidson Wildcats',
#  'UNC Greensboro': 'UNC Greensboro Spartans',
#  'Massachusetts': 'UMass Minutemen',
#  'North Dakota': 'North Dakota Fighting Hawks',
#  'Troy': 'Troy Trojans',
#  'Creighton': 'Creighton Bluejays',
#  'Brown': 'Brown Bears',
#  'Vermont': 'Vermont Catamounts',
#  'Yale': 'Yale Bulldogs',
#  'Indiana St.': 'Indiana State Sycamores',
#  'Oklahoma': 'Oklahoma Sooners',
#  'Longwood': 'Longwood Lancers',
#  'American': 'American University Eagles',
#  'Cal St. Northridge': 'CSU Northridge Matadors',
# ...
